# %% [markdown]
# <a href="https://colab.research.google.com/github/bwillow1222/ds4002MI3P2/blob/main/SCRIPTS/DataVisualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

NFLdata = pd.read_csv('https://raw.githubusercontent.com/bwillow1222/ds4002MI3P2/refs/heads/main/DATA/NFL.csv')
NBAdata = pd.read_csv('https://raw.githubusercontent.com/bwillow1222/ds4002MI3P2/refs/heads/main/DATA/NBA.csv')
MLBdata = pd.read_csv('https://raw.githubusercontent.com/bwillow1222/ds4002MI3P2/refs/heads/main/DATA/MLB.csv')
NHLdata = pd.read_csv('https://raw.githubusercontent.com/bwillow1222/ds4002MI3P2/refs/heads/main/DATA/NHL.csv')

# %%
# Adding a 'Sport' column to each dataset to differentiate them
NFLdata['Sport'] = 'NFL'
NBAdata['Sport'] = 'NBA'
MLBdata['Sport'] = 'MLB'
NHLdata['Sport'] = 'NHL'

# Reorder the sports so that NFL is at the bottom, followed by MLB, NBA, and NHL
grouped_data = grouped_data[['NFL', 'MLB', 'NBA', 'NHL']]

# Plot the stacked bar chart with the reordered sports
ax = grouped_data.plot(kind='bar', stacked=True, figsize=(10,7))

plt.title('Frequency of Entries per Year by Sport')
plt.ylabel('Number of Entries')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.legend(title='Sport')
plt.yticks([0, 1, 2, 3, 4])  # Set the y-axis scale

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Plot histograms for each sport's viewership
plt.figure(figsize=(10,8))

# NFL
plt.subplot(2, 2, 1)
plt.hist(NFLdata['Viewership (millions)'], bins=10, color='blue', alpha=0.7)
plt.title('NFL Viewership (millions)')
plt.xlabel('Viewership (millions)')
plt.ylabel('Frequency')

# MLB
plt.subplot(2, 2, 2)
plt.hist(MLBdata['Viewership (millions)'], bins=10, color='green', alpha=0.7)
plt.title('MLB Viewership (millions)')
plt.xlabel('Viewership (millions)')
plt.ylabel('Frequency')

# NBA
plt.subplot(2, 2, 3)
plt.hist(NBAdata['Viewership (millions)'], bins=10, color='red', alpha=0.7)
plt.title('NBA Viewership (millions)')
plt.xlabel('Viewership (millions)')
plt.ylabel('Frequency')

# NHL
plt.subplot(2, 2, 4)
plt.hist(NHLdata['Viewership (millions)'], bins=10, color='orange', alpha=0.7)
plt.title('NHL Viewership (millions)')
plt.xlabel('Viewership (millions)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
NFLdata['Viewership (millions)'].describe()
# Out:
# count     35.000000
# mean      96.455143
# std       12.197390
# min       73.850000
# 25%       88.170000
# 50%       93.180000
# 75%      107.585000
# max      123.400000
# Name: Viewership (millions), dtype: float64

# %%
MLBdata['Viewership (millions)'].describe()
# Out:
# count    24.000000
# mean     16.272083
# std       4.288528
# min       9.110000
# 25%      13.775000
# 50%      15.350000
# 75%      19.007500
# max      25.470000
# Name: Viewership (millions), dtype: float64

# %%
NBAdata['Viewership (millions)'].describe()
# Out:
# count    23.000000
# mean     14.747826
# std       3.723499
# min       7.500000
# 25%      12.020000
# 50%      15.140000
# 75%      17.700000
# max      20.400000
# Name: Viewership (millions), dtype: float64

# %%
NHLdata['Viewership (millions)'].describe()
# Out:
# count    16.000000
# mean      4.325625
# std       1.159252
# min       2.150000
# 25%       3.677500
# 50%       4.650000
# 75%       5.050000
# max       5.800000
# Name: Viewership (millions), dtype: float64
